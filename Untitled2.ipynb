# %%
[1]  list_kosong = []

[2]  list_buah = ["pisang", "Nanas," "Melon", "Durian"]


[3]  list_angka = [111,222,1111,2222]


[4]  list_campur = ["Nasi,200,1000,5000, "Ikan", True, False]


[5]  print ('list_kosong', list_kosong)


[6]  list_kosong []


[7]  print ('isi list buah', list_buah)


[9]  isi list buah ['Pisang', 'Nanas', 'Melon', 'Durian']
[]   print(list_buah)
# Out:
#   File "<ipython-input-1-e414d2802c00>", line 9
#     [4]  list_campur = ["Nasi,200,1000,5000, "Ikan", True, False]
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 9)

# %%
list_angka

# %%
[23] print(list_buah)
    ['Pisang',  'Nanas' ]

# %%
[29] list_buah.append("sirsak")

# %%
[30] print(list_buah)
